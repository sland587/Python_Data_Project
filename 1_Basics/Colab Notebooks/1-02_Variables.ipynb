# %% [markdown]
# # Create a Variable

# %% [markdown]
# variable_name = value

# %%
salary = 100000

# %%
salary
# Out:
# 100000

# %% [markdown]
# # Calculate Examples

# %% [markdown]
# ## Total Salary

# %% [markdown]
# Total Salary = (Base Salary) * (1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = .10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %% [markdown]
# ## Job Posting Variables

# %% [markdown]
# Example
#
#
#
# *   Create variables to store the following information about a job posting:
#   * Job ID(integer)
#   * Company Name(string)
#   * Salary Rate (string, but consider how you might store this as a numerical type for calculations)
#   * Job Work From Home (boolean)

# %%
company_name = 'DataWiz Inc.'

# %%
company_name
# Out:
# 'DataWiz Inc.'

# %%
job_wfh = True

# %%
job_wfh
# Out:
# True

# %%
job_id = 101
job_title = 'Data Analyst'
job_salary = 125000

# %%
print("Data Job Description")
print("+++++++++++++++++++++")
print("Job ID:", job_id)
print("Company Name:", company_name)
print("Job Title:", job_title)
print("Salary:", job_salary)
print("WFH:", job_wfh)
# Out:
# Data Job Description
# +++++++++++++++++++++
# Job ID: 101
# Company Name: DataWiz Inc.
# Job Title: Data Analyst
# Salary: 125000
# WFH: True

# %% [markdown]
# # Problems

# %% [markdown]
# ## Job Postings Count (1.2.1) - Problem

# %%
job_count = 42
print(job_count)
# Out:
# 42

# %% [markdown]
# ## Store Job Information (1.2.2) - Problem

# %%
job_title = 'Data Engineer'
company_name = 'DataWorks'
job_wfh = True

# Print variable values
print("Job Title:", job_title)
print("Company Name:", company_name)
print("WFH:", job_wfh)
# Out:
# Job Title: DataWorks
# Company Name: Data Engineer
# WFH: True

# %% [markdown]
# ## Calculate Total Compensation (1.2.3) - Problem

# %%
base_salary = 120000
bonus_fixed = 20000

total_compensation = base_salary + bonus_fixed

print(total_compensation)
# Out:
# 140000

# %% [markdown]
# ## Calculate Monthly Salary (1.2.4) - Problem

# %%
annual_salary = 72000
num_months = 12

monthly_salary = annual_salary // num_months # / will result in a float.  // will result in integer division and a int output
print(monthly_salary)
# Out:
# 6000

# %% [markdown]
# ## Calculate Total Compensation with Bonus (1.2.5) - Problem

# %%
job_title = 'Data Scientist'
company_name = 'AI Solutions'
base_salary = 110000
bonus_rate = .1

bonus = base_salary * bonus_rate

total_compensation = base_salary + bonus
print("Job Title: ", job_title, ", Company: ", company_name, ", Total Compensaion: ", total_compensation)
# Out:
# Job Title:  Data Scientist , Company:  AI Solutions , Total Compensaion:  121000.0
