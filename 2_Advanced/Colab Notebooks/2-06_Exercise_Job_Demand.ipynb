# %% [markdown]
# # Exercise: Analyzing Data Science Job Demand

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## Breakdown of Steps

# %% [markdown]
# 1. Filter data to only US jobs
# 1. Create a month name column generated from the job_posted_date column
# 1. Pivot Data to put in a plottable format
#     * Aggregate by size which will give us proper job posting counts
# 1. Reset_index as starting point so we aren't trying to sort on month name; We can then add the month number as the index to sort on in a later step
# 1. Create Month number column
#     * Convert the month name back into a datetime and then extract the month number and assign it to a new column 'month_no'
# 1. Sort by the month_no
# 1. Set the index to the 'job_posted_month'
# 1. Remove the added month_no column now that it's properly sorted.
# 1. Get top 3 Job Titles with highest counts from the us jobs data frame to help filter chart down for readablity and focus
# 1. Filter the pivot table down to top 3 job titles
# 1. Plot line chart with proper labels, title, etc.

# %%
# Filter data to only US jobs
df_US = df[df['job_country'] == 'United States']

df_US
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %% [markdown]
# [Date Format code documentation from standard python library](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)

# %%
# Create a month name column generated from the job_posted_date column
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')

df_US
# Out:
# /tmp/ipykernel_9435/1502874820.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# ...

# %%
# Pivot Data to put in a plottable format
df_US_pivot = df_US.pivot_table(index='job_posted_month',columns='job_title_short', aggfunc='size')

df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
# Reset_index as starting point so we aren't trying to sort on month name; We can then add the month number as the index to sort on in a later step
df_US_pivot.reset_index(inplace=True)
df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
# Create Month number column
# Convert the month name back into a datetime and then extract the month number and assign it to a new column 'month_no'
df_US_pivot['month_no'] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month

df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
# Sort by the month_no
df_US_pivot.sort_values(by='month_no', inplace=True)
df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               527              36
# 3                       February               447              24
# 7                          March               438              19
# 0                          April               565              40
# 8                            May               279              20
# 6                           June               446              32
# 5                           July               581              39
# 1                         August               903              39
# 11                     September               897              50
# 10                       October               932              48
# 9                       November               719              36
# 2                       December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
# Set the index to the 'job_posted_month'
df_US_pivot.set_index(keys='job_posted_month', inplace=True)
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
# Remove the added month_no column now that it's properly sorted.
df_US_pivot.drop(columns='month_no', inplace=True)
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
# Plot the pivot table
df_US_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
# Get top 3 Job Titles with highest counts from the us jobs data frame to help filter chart down for readablity and focus
top_3 = df_US['job_title_short'].value_counts().sort_values(ascending=False).head(3)

# The job_title_short is the index in the resulting series; the counts are the values.  
# Grab the index(job_title_short) from the series and convert it to a list
top_3 = top_3.index.to_list()
top_3
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
# Plot Pivot table again.  This time filtering list down to top 3
df_US_pivot[top_3].plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
# Cleanup Chart
df_US_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()

# %% [markdown]
# ## Full Code

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# Filter data to only US jobs
df_US = df[df['job_country'] == 'United States']

# Create a month name column generated from the job_posted_date column
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')

# Pivot Data to put in a plottable format
df_US_pivot = df_US.pivot_table(index='job_posted_month',columns='job_title_short', aggfunc='size')

# Reset_index as starting point so we aren't trying to sort on month name; We can then add the month number as the index to sort on in a later step
df_US_pivot.reset_index(inplace=True)

# Create Month number column
# Convert the month name back into a datetime and then extract the month number and assign it to a new column 'month_no'
df_US_pivot['month_no'] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month

# Sort by the month_no
df_US_pivot.sort_values(by='month_no', inplace=True)

# Set the index to the 'job_posted_month'
df_US_pivot.set_index(keys='job_posted_month', inplace=True)

# Remove the added month_no column now that it's properly sorted.
df_US_pivot.drop(columns='month_no', inplace=True)

# Get top 3 Job Titles with highest counts from the us jobs data frame to help filter chart down for readablity and focus
top_3 = df_US['job_title_short'].value_counts().sort_values(ascending=False).head(3)

# The job_title_short is the index in the resulting series; the counts are the values.  
# Grab the index(job_title_short) from the series and convert it to a list
top_3 = top_3.index.to_list()


# Cleanup and Plot Chart
df_US_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_9435/3071505840.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
